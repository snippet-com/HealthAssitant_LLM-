# %% [markdown]
# <a href="https://colab.research.google.com/github/snippet-com/HealthAssitant_LLM-/blob/main/FIneTunedChatBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openai

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

# %%
SYSTEM_PROMPT = """
You are a helpful health assistant.

- Give general health information only
- Do NOT diagnose
- Do NOT give dosage or prescriptions
- Keep answers simple
- Suggest consulting a doctor when needed
"""

def ask_bot(query):
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": SYSTEM_PROMPT},
            {"role": "user", "content": query}
        ],
        temperature=0.5
    )

    return response.choices[0].message.content

# %%
print(ask_bot("What causes a sore throat?"))

# %%
import streamlit as st

st.title("Health Chatbot")

user_input = st.text_input("Ask a health question:")

if user_input:
    response = safe_ask(user_input)
    st.write(response)

# %%
st.write("⚠️ This chatbot provides general health information only. It is not a doctor.")
